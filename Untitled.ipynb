# %%
import pandas as pd

# Create a sample dataframe
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Assign new column names
df.columns = ['X', 'Y']

df
# Out:
#    X  Y
# 0  1  4
# 1  2  5
# 2  3  6
